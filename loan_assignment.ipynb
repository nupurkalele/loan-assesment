# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv("Loan_Train.csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
#Q1
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
sns.countplot(df['Gender'], hue=df['Loan_Status'])

# %%
by_male=df.groupby(['Gender']=='Male')
by_male.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-f0a1f5e2c6f0> in <module>
# ----> 1 by_male=df.groupby(['Gender']=='Male')
#       2 by_male.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5799         axis = self._get_axis_number(axis)
#    5800
# -> 5801         return groupby_generic.DataFrameGroupBy(
#    5802             obj=self,
#    5803             keys=by,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     401             from pandas.core.groupby.grouper import get_grouper
#     402
# --> 403             grouper, exclusions, obj = get_grouper(
#     404                 obj,
# ...

# %%
new_df=df[['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term']]
print(new_df)
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
# [614 rows x 4 columns]

# %%
new_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000

# %%
result = df.groupby('Gender').agg('Loan_Status')
print(result)
result.head()
# Out:
# ...
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
# 17     N
# 23     N
# 29     Y
# 37     Y
# 45     Y
# 48     N
# 126    Y
# 171    Y
# 188    Y
# 314    N
# Name: Loan_Status, dtype: object

# %%
gender_df=df[df['Loan_Status']=='Y']
print(gender_df.shape)
print(df.shape)
# Out:
# (422, 13)
# (614, 13)

# %%
#sns.countplot(df['Gender'], hue=df['Loan_Status'])

# %%
gender_df = df.loc[((df['Credit_History']==1) & (df['Loan_Status']=='Y'))]
print(gender_df.reset_index())
print(gender_df.shape)
# Out:
#      index   Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0        0  LP001002    Male      No          0      Graduate            No
# 1        2  LP001005    Male     Yes          0      Graduate           Yes
# 2        3  LP001006    Male     Yes          0  Not Graduate            No
# 3        4  LP001008    Male      No          0      Graduate            No
# 4        5  LP001011    Male     Yes          2      Graduate           Yes
# ..     ...       ...     ...     ...        ...           ...           ...
# 373    608  LP002974    Male     Yes          0      Graduate            No
# 374    609  LP002978  Female      No          0      Graduate            No
# 375    610  LP002979    Male     Yes         3+      Graduate            No
# 376    611  LP002983    Male     Yes          1      Graduate            No
# 377    612  LP002984    Male     Yes          2      Graduate            No
#
# ...

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv("Loan_Train.csv")

#Q1
#information
print(df.info())

#Q2
#compute the mean, max, quantile and min of applicant income and co applicant income seperately using pandas.

new_df=df[['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term']]
new_df.describe()

#Q3
#plot the histogram of applicant income with 10 bins and co applicant.

df['ApplicantIncome'].shape[0]
plt.hist(df['ApplicantIncome'],bins=50)

#Q4 
#dataframe of males and females whose loan status is yes (approved)
gender_df = df.loc[((df['Gender']=='Male') & (df['Loan_Status']=='Y'))]
gender_df = df.loc[((df['Gender']=='Female') & (df['Loan_Status']=='Y'))]

print(gender_df.reset_index())
print(gender_df.shape)

#Q5 
#df of males whose loan is sactioned
gender_df = df.loc[((df['Gender']=='Male') & (df['Loan_Status']=='Y'))]
print(gender_df.shape)

#Q6
#df of ppl having credit hisrory 1 and loan status as yes
saction_df = df.loc[((df['Credit_History']==1) & (df['Loan_Status']=='Y'))]
print(saction_df.reset_index())
print(saction_df.shape)

#Q7
#pie chart of males and female applicants for which loan is approved.

status_df=df.loc[((df['Loan_Status']=='Y'))]
print(status_df.reset_index())
print(status_df.shape)

status_df["Gender"].value_counts().plot.pie()


#Q7 but using where clause
sorted_df=df.where(df['Loan_Status']=='Y')
print(sorted_df)
sorted_df['Gender'].value_counts().plot.pie()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB
# None
# ...

# %%
#Q8
#calculate applicants whose inome is greater than mean income
new_df=df[['ApplicantIncome']]
a=new_df.mean()
print (a)
# Out:
# ApplicantIncome    5403.459283
# dtype: float64
